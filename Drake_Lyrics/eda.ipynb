# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.style as style
# %matplotlib inline
import seaborn as sns
from scipy import stats

import warnings
warnings.filterwarnings('ignore')

plt.rc('xtick', labelsize = 10)
plt.rc('ytick', labelsize = 10)
plt.rc('axes', labelsize = 12, labelpad = 5)

# %%
df = pd.read_csv('drake_songs.csv', index_col='Unnamed: 0')

# %%
df.sample(5)
# Out:
#                                     title  \
# 40                       Bad Meaning Good
# 475                           Still Drake
# 147                               Fdfgsdg
# 349  OVO Sound Radio Episode 23 Tracklist
# 568                            Video Girl
#
#                                          album release_date  \
# 40                        Room for Improvement   2006-02-14
# 475                                   <single>          NaN
# 147                                   <single>   2022-12-30
# 349  OVO Sound Radio Tracklists - Season 1 & 2   2016-06-04
# 568                       Room for Improvement   2006-02-14
#
#              featured_artists          producer_artists  \
# 40   ['Slakah the Beatchild']  ['Slakah the Beatchild']
# 475            ['Trey Songz']    ['Mel-Man', 'Dr. Dre']
# 147                        []                        []
# 349                        []                        []
# 568                        []     ['Dan “DFS” Johnson']
#
#                                 writer_artists  genius_track_id  \
# 40                   ['Byram Joseph', 'Drake']            18067
# 475                    ['Trey Songz', 'Drake']            55185
# 147                                         []          8648113
# 349                                         []          2489011
# 568  ['Dan “DFS” Johnson', 'Drake', 'Boi-1da']             5033
#
#      genius_album_id
# 40            2625.0
# 475              NaN
# 147              NaN
# 349         128797.0
# 568           2625.0

# %%
df.dtypes
# Out:
# title                object
# album                object
# release_date         object
# featured_artists     object
# producer_artists     object
# writer_artists       object
# genius_track_id       int64
# genius_album_id     float64
# dtype: object

# %%
for column in ['featured_artists', 'producer_artists', 'writer_artists']:
    df[column] = df[column].apply(lambda x: x.strip('[]').replace("'",""))
    df[column] = df[column].apply(lambda x: x.split(','))

# %%
df.sample(10)
# Out:
#                                              title  \
# 210                           I Guess It’s Fuck Me
# 87                                    Concentrate*
# 546                                       Trophies
# 68                            Cannonball (Snippet)
# 470  Started From the Bottom Deluxe - Don’t Delete
# 50                                      Between Us
# 142                             Fall For Your Type
# 303                                    My New Shit
# 327                                   One Man Show
# 338           OVO Sound Radio Episode 13 Tracklist
#
#                                          album release_date  \
# 210                                   Her Loss   2022-11-04
# 87                                    <single>          NaN
# 546             Young Money: Rise of an Empire   2013-12-30
# 68                            Heartbreak Drake   2009-12-19
# 470                                   <single>          NaN
# 50                                    <single>   2009-09-01
# 142                                   <single>          NaN
# 303         Black Diamond 8 (Audible Narcotic)          NaN
# 327                                   <single>   2010-05-10
# 338  OVO Sound Radio Tracklists - Season 1 & 2   2016-01-16
#
#            featured_artists                    producer_artists  \
# 210                      []                       [TheLoudPack]
# 87                       []                                  []
# 546                      []  [Hit-Boy,  Rey Reel,  40,  Hagler]
# 68           [Colin Munroe]                                  []
# 470                      []                                  []
# 50   [Slakah the Beatchild]                             [Häzel]
# 142                      []                                  []
# 303                      []                             [Nottz]
# 327                      []                                  []
# 338                      []                                  []
#
#                                         writer_artists  genius_track_id  \
# 210   [Drake,  IsThisShiv,  MixedByTheBest,  Dougie F]          8524045
# 87                                                  []          5701120
# 546  [Rey Reel,  Sharon Abshire,  Bernard Joseph Gé...           225050
# 68                              [Colin Munroe,  Drake]          3175723
# 470                                                 []          2318813
# 50                      [Slakah the Beatchild,  Drake]            81686
# 142                                            [Drake]             1194
# 303                                    [Nottz,  Drake]             2954
# 327                                                 []          3893523
# 338                                                 []          2408264
#
#      genius_album_id
# 210         966485.0
# 87               NaN
# 546          78014.0
# 68          359632.0
# 470              NaN
# 50               NaN
# 142              NaN
# 303         924577.0
# 327              NaN
# 338         128797.0

# %%
commercial_releases = [
    'So Far Gone',
    'Thank Me Later',
    'Take Care',
    'Care Package',
    'Nothing Was the Same',
    'If You’re Reading This It’s Too Late',
    'Views',
    'What a Time To Be Alive',
    'More Life',
    'Scary Hours',
    'Scorpion',
    'The Best in the World Pack',
    'Dark Lane Demo Tapes',
    'Scary Hours 2',
    'Certified Lover Boy',
    'Honestly, Nevermind',
    'Her Loss'
]

# %%
df = df[(df['album'].isin(commercial_releases))]

# %%
df['album'].value_counts()
# Out:
# Scorpion                                24
# More Life                               23
# Take Care                               22
# Certified Lover Boy                     20
# Views                                   20
# If You’re Reading This It’s Too Late    19
# So Far Gone                             18
# Nothing Was the Same                    16
# Thank Me Later                          16
# Honestly, Nevermind                     14
# Care Package                            13
# Dark Lane Demo Tapes                    13
# Her Loss                                 4
# Scary Hours 2                            3
# The Best in the World Pack               2
# What a Time To Be Alive                  1
# Scary Hours                              1
# Name: album, dtype: int64

# %%
df.sample(5)
# Out:
#                                  title                 album release_date  \
# 312                      Nice For What              Scorpion   2018-04-06
# 423  Pound Cake / Paris Morton Music 2  Nothing Was the Same   2013-09-24
# 163             From Florida With Love  Dark Lane Demo Tapes   2020-05-01
# 469            Started from the Bottom  Nothing Was the Same   2013-02-01
# 252                  Let’s Call It Off           So Far Gone   2009-02-13
#
#            featured_artists  \
# 312                      []
# 423                 [JAY-Z]
# 163                      []
# 469                      []
# 252  [Peter Bjorn and John]
#
#                                       producer_artists  \
# 312      [Murda Beatz,  BlaqNmilD,  40,  Corey Litwin]
# 423  [The Order,  Matthew Burnett,  Detail,  Jordan...
# 163                                   [40,  MexikoDro]
# 469                                 [40,  Mike Zombie]
# 252                                    [Björn Yttling]
#
#                                         writer_artists  genius_track_id  \
# 312  [Birdman,  Raekwon,  Glenishe Rowe,  RZA,  Gho...          3580132
# 423  [Jim Eliot,  Method Man,  RZA,  Ellie Goulding...           218330
# 163                           [40,  MexikoDro,  Drake]          5447963
# 469                         [Drake,  40,  Mike Zombie]           113898
# 252                [40,  Peter Bjorn and John,  Drake]             4663
#
#      genius_album_id
# 312         420582.0
# 423          40475.0
# 163         630537.0
# 469          40475.0
# 252           2627.0

# %%
feature_count = {}

# %%
for artists in df['featured_artists']:
    if artists[0] != '':
        for artist in artists:
            if artist in feature_count:
                feature_count[artist] += 1
            else:
                feature_count[artist] = 0
